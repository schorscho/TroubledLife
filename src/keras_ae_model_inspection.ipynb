# %%
import os

from math import sqrt

import numpy as np

import pandas as pd

from sklearn.metrics import mean_squared_error, accuracy_score, precision_score, recall_score, classification_report, confusion_matrix

import troubled_life_all as tla
from troubled_life_all import TL

# %%
_, _, troubled_test_data = tla.load_all_data(
        clean_train_set=False,
        clean_val_set=False,
        troubled_test_set=True)

test_results = pd.read_csv(
    os.path.join(TL.OUTPUT_DIR,
                 'MV03R00_OV01R00_DP01R00_TR009_20180309-163927_SE000_EP398-00022.9634_results.csv'))
# Out:
# 2018-03-10 10:33:18,409 - TROUBLED_LIFE - INFO - Loading prepared test data ...
# 2018-03-10 10:33:18,492 - TROUBLED_LIFE - INFO - Loading prepared test data done.

# %%
test_result[test_result["pred_correct"] == False]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>certainty</th>
#       <th>label</th>
#       <th>label_pred</th>
#       <th>pol_mse</th>
#       <th>pred_correct</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2461</th>
#       <td>128.328352</td>
#       <td>False</td>
#       <td>True</td>
#       <td>129328.352399</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
troubled_test_data.loc[2461]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>biz_proc</th>
#       <th>tariff</th>
#       <th>interest</th>
#       <th>sum_insured</th>
#       <th>premium</th>
#       <th>current_capital</th>
#       <th>troubled</th>
#     </tr>
#     <tr>
#       <th>current_year</th>
#       <th>version</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="4" valign="top">0</th>
#       <th>0</th>
#       <td>initial</td>
#       <td>3</td>
#       <td>0.05</td>
#       <td>117787.655789</td>
# ...

# %%
test_result
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>certainty</th>
#       <th>label</th>
#       <th>label_pred</th>
#       <th>pol_mse</th>
#       <th>pred_correct</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1001</th>
#       <td>0.997660</td>
#       <td>False</td>
#       <td>False</td>
#       <td>2.339968</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1002</th>
#       <td>0.999244</td>
#       <td>False</td>
#       <td>False</td>
#       <td>0.755994</td>
#       <td>True</td>
# ...
